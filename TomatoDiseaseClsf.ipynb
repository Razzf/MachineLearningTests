# %% [markdown]
# <a href="https://colab.research.google.com/github/Razzf/MachineLearningTests/blob/master/TomatoDiseaseClsf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2

# %%
DATADIR = "/content/drive/My Drive/Tomato classifier/Tomato-data"
CATEGORIES = ['Bacterial_Spot', 'Early_Blight', 'Healthy',
              'Late_Blight', 'Leaf_Mold', 'Septoria_Leaf_Spot',
              'Target_Spot', 'Two-Spotted_Spider_Mite',
              'Vosaic_Virus', 'YellowLeaf__Curl_Virus']

# %%
for category in CATEGORIES:
  path = os.path.join(DATADIR, category)
  print(path)
  for img in os.listdir(path):
    img_path = os.path.join(path, img)
    print(img_path)
    img_array = cv2.imread(img_path)
    img_array = cv2.cvtColor(img_array, cv2.COLOR_BGR2RGB)
    plt.imshow(img_array, cmap='binary')
    plt.show()
    break
  break
# Out:
# /content/drive/My Drive/Tomato classifier/Tomato-data/Bacterial_Spot
# /content/drive/My Drive/Tomato classifier/Tomato-data/Bacterial_Spot/06f23987-e01b-40dc-98ef-a5b33e86bc90___UF.GRC_BS_Lab Leaf 0308.JPG

# %%
print(img_array)
# Out:
# [[[ 74  79  78]
#   [ 77  82  81]
#   [ 81  86  85]
#   ...
#   [152 149 151]
#   [147 144 146]
#   [142 139 141]]
#
#  [[ 76  81  80]
#   [ 77  82  81]
#   [ 80  85  84]
#   ...
#   [140 137 139]
#   [141 138 140]
#   [141 138 140]]
#
#  [[ 80  85  84]
#   [ 80  85  84]
#   [ 81  86  85]
#   ...
#   [141 138 140]
#   [146 143 145]
#   [150 147 149]]
#
#  ...
#
#  [[ 54  45  42]
#   [ 53  44  41]
#   [ 53  44  41]
#   ...
#   [156 163 166]
#   [157 164 167]
#   [157 164 167]]
#
#  [[ 52  43  40]
#   [ 49  40  37]
#   [ 47  38  35]
#   ...
#   [155 161 166]
#   [156 162 167]
#   [156 162 167]]
#
#  [[ 51  42  39]
#   [ 46  37  34]
#   [ 42  33  30]
#   ...
#   [155 161 166]
#   [156 162 167]
#   [156 162 167]]]
